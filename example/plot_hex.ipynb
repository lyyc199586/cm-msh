# %%
from pathlib import Path
from cm_msh.plot.mesh_plotter import MeshPlotter

msh_path = Path("./meshes/hex_6x6.msh")
plotter = MeshPlotter(msh_path)

plotter.plot(show_node_ids=False, show_element_ids=False, show_boundaries=False, legend=False)
# Out:
# <Axes: title={'center': 'Mesh: hex_6x6.msh'}>
